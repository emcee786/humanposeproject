# %%
from ultralytics import YOLO

#load a model
model = YOLO('yolov8n-pose.pt')

#predict with the model
#results = model('https://ultralytics.com/images/bus.jpg') #predict on an image

#add image source
source = 'C:\\Users\\Fists\\Artificial Intelligence tasks folder\\Pose Task\\data\\images\\train\\0\\squat_1000121.jpg'

model.predict(source, save=True, imgsz=320, conf=0.5)
# Out:
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████| 6.51M/6.51M [00:02<00:00, 3.15MB/s]
#
# image 1/1 C:\Users\Fists\Artificial Intelligence tasks folder\Pose Task\data\images\train\0\squat_1000121.jpg: 256x320 1 person, 106.9ms
# Speed: 2.0ms preprocess, 106.9ms inference, 4.4ms postprocess per image at shape (1, 3, 256, 320)
# Results saved to C:\Users\Fists\runs\pose\predict3
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'person'}
#  orig_img: array([[[ 46,  41,  38],
#          [ 47,  42,  39],
#          [ 47,  42,  39],
#          ...,
#          [161, 190, 235],
#          [159, 190, 235],
#          [159, 190, 235]],
#
#         [[ 46,  41,  38],
#          [ 47,  42,  39],
#          [ 47,  42,  39],
#          ...,
#          [159, 190, 235],
#          [159, 190, 235],
# ...

# %%
#Video keypoint detection

#add video source
source = 'Squat_14.mp4'
model.predict(source, save=True, imgsz=320, conf=0.5)
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/101) C:\Users\Fists\Artificial Intelligence tasks folder\Yolov8 Keypoint detection\Squat_14.mp4: 192x320 1 person, 88.0ms
# video 1/1 (2/101) C:\Users\Fists\Artificial Intelligence tasks folder\Yolov8 Keypoint detection\Squat_14.mp4: 192x320 1 person, 55.7ms
# video 1/1 (3/101) C:\Users\Fists\Artificial Intelligence tasks folder\Yolov8 Keypoint detection\Squat_14.mp4: 192x320 1 person, 56.0ms
# ...

# %%
#Keypoint detection vie live feed

import cv2
from ultralytics import YOLO

#load model
model = YOLO('yolov8n-pose.pt')

#open the video file
video_path = 0 #opening camera
cap = cv2.VideoCapture(video_path)

#loop through the video frames
while cap.isOpened():
    #read a frame from the video
    success, frame = cap.read()
    
    if success:
        #Run YOLOv8 inference on the frame
        results = model(frame, save=True)
        
        #Visualise the results on the frame
        annotated_frame = results[0].plot()
        
        #Display the annotated frame
        cv2.imshow("YOLOv8 Inference", annotated_frame)
        
        #Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF -- ord("Q"):
            break
    else:
        #break the loop if the end of the video is reached
        break
        
#Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 148.2ms
# Speed: 3.0ms preprocess, 148.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to C:\Users\Fists\runs\pose\predict7
